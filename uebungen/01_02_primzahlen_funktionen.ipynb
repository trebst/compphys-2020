# %% [markdown]
# <table style="width: 100%; border-style: none;">
# <tr style="border-style: none">
# <td style="border-style: none; width: 1%; text-align: left; font-size: 16px">Institut f&uuml;r Theoretische Physik<br /> Universit&auml;t zu K&ouml;ln</td>
# <td style="border-style: none; width: 1%; font-size: 16px">&nbsp;</td>
# <td style="border-style: none; width: 1%; text-align: right; font-size: 16px">Prof. Dr. Simon Trebst<br />Jan Attig</td>
# </tr>
# </table>
# <hr>
# <h1 style="font-weight:bold; text-align: center; margin: 0px; font-size: 30px; padding:0px;">Computerphysik</h1>
# <h1 style="font-weight:bold; text-align: center; margin: 0px; font-size: 30px; padding:0px;">Übungsblatt 1</h1>
# <hr>
# <h3 style="font-weight:bold; text-align: center; margin: 0px; font-size: 20px; padding:0px; margin-bottom: 20px;">Sommersemester 2020</h3>
# <hr>
#
# **Website** [http://www.thp.uni-koeln.de/trebst/Lectures/2020-CompPhys.shtml](http://www.thp.uni-koeln.de/trebst/Lectures/2020-CompPhys.shtml)
#
# **Abgabe**:  -- kein Abgabe (Präsenzübung) --
#
# **Besprechung**:  29.4.2020 - 30.4.2020 (Präsenzübung)
#
# **Name**: <font color="red">Bitte geben Sie ihren Namen an</font>
#
# **Matrikelnummer**: <font color="red">Bitte geben Sie ihre Matrikelnummer an</font>

# %% [markdown]
# <table style="border-style: none; width: 100%"><tr style="border-style: none;">
# <td style="border-style: none; width: 1%; text-align: left; font-size: 25px; font-weight: bold; text-decoration: underline">Aufgaben auf Übungsblatt 1</td>
# <td style="border-style: none; width: 1%; text-align: right; font-size: 15px"></td></tr></table>
#
# - Listen und Fibonacci-Zahlen [0 Punkte]
# - **Primzahlen und Funktionen** [0 Punkte]
# - Primzahlen geplottet [0 Punkte]

# %% [markdown]
# <table style="border-style: none; width: 100%"><tr style="border-style: none;">
# <td style="border-style: none; width: 1%; text-align: left; font-size: 25px; font-weight: bold; text-decoration: underline">Primzahlen und Funktionen</td>
# <td style="border-style: none; width: 1%; text-align: right; font-size: 15px">[0 Punkte]</td></tr></table>

# %% [markdown]
# In dieser Aufgabe möchten wir die Implementation aus der Aufgabe *Primzahlen* erweitern und die Prüfung, ob eine Zahl `N` eine Primzahl ist, in eine Funktion definieren. Dazu möchten wir ein weiteres Konzept diskutieren, nämlich das der **Funktion**. Grundsätzlich versteht man unter einer Funktion einen zusammengefassten Block Code, der mit bestimmten Parametern aufgerufen werden kann und möglicherweise einen Wert an den Aufrufer zurückgibt. Funktionen werden vor allem benutzt, um doppelte Codeblöcke zu vermeiden und um Codes besser zu strukturieren.
#
# In Julia sieht die Syntax für die Definition einer Funktion wie folgt aus:
#
# ![Functions.svg](attachment:Functions.svg)
#
# Die angegebene Funktion könnte dann z.B. mit `myfunction(4)` aufgerufen werden.

# %% [markdown]
# ### a) Erste Funktionsdefinitionen in Julia
#
# Erstellen Sie in der nachfolgenden Zelle eine kleine Funktion namens `quadrat`, die das Quadrat einer übergebenen Zahl zurückgeben soll.
#
# Testen Sie danach Ihre Definition, indem Sie die Zelle darunter ausführen und überprüfen, ob Sie eine richtige Ausgabe erhalten.

# %%
# DEFINIEREN SIE HIER IHRE FUNKTION

# %%
# FÜHREN SIE DIESEN CODE ALS TEST AUS
z = 3
println("Das Quadrat von ", z, " ist ", quadrat(z))

# %% [markdown]
# ### b) Implementation einer Funktion zum Test auf Primzahlen
#
# In der Aufgabe *Primzahlen* haben Sie bereits einen kleinen Code geschrieben, der eine vorgegebene Zahl `N` darauf testet, ob sie eine Primzahl ist oder nicht. Jetzt sollen Sie, ausgehend von diesem Code, eine Funktion `ist_primzahl` schreiben, die eine übergebene Zahl `N` testet, ob sie eine Primzahl ist. In diesem Falle soll die Funktion den `Bool` Wert `true` zurückgeben, andernfalls den `Bool` Wert `false`.
#
# Sie können Ihre Funktionsdefinition erneut mit der übernächsten Zelle testen.

# %%
# DEFINIEREN SIE HIER IHRE FUNKTION

# %%
# FÜHREN SIE DIESEN CODE ALS TEST AUS
z = 17
println(z, " ist eine Primzahl: ", ist_primzahl(z))
